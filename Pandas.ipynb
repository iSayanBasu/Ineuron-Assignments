# %%
import pandas as pd

# %%
#Read Data
pd = pd.read_csv('D:/Python/Data Science Ineuron/Data Set/submission.csv')

# %%
pd.head(5)
# Out:
#    Unnamed: 0  data
# 0           0     0
# 1           1     1
# 2           2     2
# 3           3     3
# 4           4     4

# %%
pd.tail(20)
# Out:
#      Unnamed: 0  data
# 980         980   980
# 981         981   981
# 982         982   982
# 983         983   983
# 984         984   984
# 985         985   985
# 986         986   986
# 987         987   987
# 988         988   988
# 989         989   989
# 990         990   990
# 991         991   991
# 992         992   992
# 993         993   993
# 994         994   994
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999

# %%
df = pd.read_csv('D:/Python/Data Science Ineuron/Data Set/submission.csv')
df
# Out:
#      Unnamed: 0  data
# 0             0     0
# 1             1     1
# 2             2     2
# 3             3     3
# 4             4     4
# ..          ...   ...
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999
#
# [1000 rows x 2 columns]

# %%
df.tail()
# Out:
#      Unnamed: 0  data
# 995         995   995
# 996         996   996
# 997         997   997
# 998         998   998
# 999         999   999

# %%
df1=df.head()
df1
# Out:
#    Unnamed: 0  data
# 0           0     0
# 1           1     1
# 2           2     2
# 3           3     3
# 4           4     4

# %%
df1.to_csv('D:/Python/Data Science Ineuron/Data Set/test.csv')

# %%
data=pd.read_csv('D:/Python/Data Science Ineuron/Data Set/test.csv', header = None , names = ['a','b','c','d'], na_values= 2)
data
# Out:
#      a           b     c   d
# 0  NaN  Unnamed: 0  data NaN
# 1  0.0           0     0 NaN
# 2  1.0           1     1 NaN
# 3  NaN         NaN   NaN NaN
# 4  3.0           3     3 NaN
# 5  4.0           4     4 NaN

# %%
df1.describe()
# Out:
#        Unnamed: 0      data
# count    5.000000  5.000000
# mean     2.000000  2.000000
# std      1.581139  1.581139
# min      0.000000  0.000000
# 25%      1.000000  1.000000
# 50%      2.000000  2.000000
# 75%      3.000000  3.000000
# max      4.000000  4.000000

# %%
df1.dtypes
# Out:
# Unnamed: 0    int64
# data          int64
# dtype: object

# %%
df1
# Out:
#    Unnamed: 0  data
# 0           0     0
# 1           1     1
# 2           2     2
# 3           3     3
# 4           4     4

# %%
df1.to_csv('D:/Python/Data Science Ineuron/Data Set/test1.csv', index = False)

# %%
ranking= pd.read_html('https://www.icc-cricket.com/rankings/mens/team-rankings/test')
ranking
# Out:
# [   Pos           Team  T  Matches  M  Points  P  Rating  R
#  0    1   New Zealand  NZ          21       2593        123
#  1    2        India  IND          24       2914        121
#  2    3    Australia  AUS          17       1844        108
#  3    4      England  ENG          35       3753        107
#  4    5     Pakistan  PAK          24       2247         94
#  5    6   West Indies  WI          24       2024         84
#  6    7  South Africa  SA          16       1273         80
#  7    8     Sri Lanka  SL          27       2095         78
#  8    9   Bangladesh  BAN          15        694         46
#  9   10     Zimbabwe  ZIM          10        346         35]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-7218223f0a1a> in <module>
# ----> 1 ranking[0], index = None
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
titanic= pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
